# %%
import pandas as pd
import os
csv_path='D:\machine_learning_Data\transaction_price_data'
csv_list=os.listdir(csv_path)

csv_list_py=[file for file in csv_list if file.endswith('csv')]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-944acb027f9a> in <module>
#       2 import os
#       3 csv_path='D:\machine_learning_Data\transaction_price_data'
# ----> 4 csv_list=os.listdir(csv_path)
#       5
#       6 csv_list_py=[file for file in csv_list if file.endswith('csv')]
#
# OSError: [WinError 123] 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다: 'D:\\machine_learning_Data\transaction_price_data'

# %%
csv_list_py
# Out:
# ['건축허가현황.csv',
#  '국내건설수주액.csv',
#  '미분양주택현황.csv',
#  '아파트 실거래가격지수.csv',
#  '유형별_주택월세통합가격지수.csv',
#  '주택건설인허가실적.csv',
#  '주택매매가격지수(KB).csv',
#  '주택전세가격지수(KB).csv',
#  '지역별_지가변동률.csv']

# %%
df=pd.read_csv('E:\machine_learning_data\한국 부동산 데이터 시각화 경진대회_data\지역별_지가변동률.csv')
df
# Out:
#      Unnamed: 0  전국[%]  서울[%]  부산[%]  대구[%]  인천[%]  광주[%]  대전[%]  울산[%]  \
# 0    2005-01-01  0.226  0.192  0.083  0.212  0.145  0.156  0.196  0.137
# 1    2005-02-01  0.184  0.140  0.065  0.208  0.208  0.080  0.206  0.153
# 2    2005-03-01  0.348  0.403  0.119  0.278  0.470  0.154  0.674  0.180
# 3    2005-04-01  0.525  0.725  0.151  0.258  0.751  0.159  0.917  0.149
# 4    2005-05-01  0.562  0.590  0.185  0.254  0.693  0.291  0.850  0.131
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 189  2020-10-01  0.294  0.375  0.337  0.265  0.295  0.277  0.375  0.138
# 190  2020-11-01  0.322  0.405  0.458  0.326  0.287  0.370  0.416  0.161
# 191  2020-12-01  0.343  0.437  0.444  0.387  0.295  0.389  0.417  0.180
# 192  2021-01-01  0.311  0.408  0.281  0.342  0.297  0.305  0.386  0.184
# 193  2021-02-01  0.311  0.418  0.289  0.321  0.284  0.235  0.363  0.177
#
#      세종[%]  경기[%]  강원[%]  충북[%]  충남[%]  전북[%]  전남[%]  경북[%]  경남[%]  제주[%]
# ...

# %%
import pandas as pd
import os
csv_path='E:\machine_learning_data\아파트 실거래가 예측'
csv_list=os.listdir(csv_path)

csv_list_py=[file for file in csv_list if file.endswith('csv')]
csv_list_py
# Out:
# ['day_care_center.csv', 'park.csv', 'submission.csv', 'test.csv', 'train.csv']

# %%
df=pd.read_csv('E:\machine_learning_data\아파트 실거래가 예측\\train.csv')
# Out:
#    transaction_id  apartment_id   city dong   jibun       apt  \
# 0               0          7622  서울특별시  신교동    6-13  신현(101동)
# 1               1          5399  서울특별시  필운동     142    사직파크맨션
# 2               2          3578  서울특별시  필운동   174-1    두레엘리시안
# 3               3         10957  서울특별시  내수동      95     파크팰리스
# 4               4         10639  서울특별시  내수동  110-15      킹스매너
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
# 2   필운동 174-1 두레엘리시안               84.74                2007
# 3       내수동 95 파크팰리스              146.39                2003
# 4    내수동 110-15 킹스매너              194.43                2004
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000
# ...

# %%
df.head(2)
# Out:
#    transaction_id  apartment_id   city dong jibun       apt  \
# 0               0          7622  서울특별시  신교동  6-13  신현(101동)
# 1               1          5399  서울특별시  필운동   142    사직파크맨션
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000

# %%
df=pd.read_csv('E:\machine_learning_data\아파트 실거래가 예측\\park.csv')

# %%
df.head(2)
# Out:
#     city  gu dong park_name park_type  park_area park_exercise_facility  \
# 0  부산광역시  남구  대연동      대연공원      근린공원    55227.0                    NaN
# 1  부산광역시  남구  대연동      당곡공원      역사공원    75465.0                    NaN
#
#   park_entertainment_facility park_benefit_facility park_cultural_facitiy  \
# 0                         NaN                   NaN                   NaN
# 1                         NaN                   NaN                   NaN
#
#   park_facility_other  park_open_year reference_date
# 0                 NaN          1944.0     2018-08-14
# 1                 NaN          1944.0     2018-08-14

# %%
df=pd.read_csv('E:\machine_learning_data\아파트 실거래가 예측\\day_care_center.csv')
df.groupby('day_care_type').count()
# Out:
#                city    gu  day_care_name  day_care_baby_num  teacher_num  \
# day_care_type
# 가정             3120  3120           3120               3120         3052
# 국공립            1408  1408           1408               1408         1348
# 민간             2492  2492           2492               2492         2424
# 법인·단체           113   113            113                113          113
# 사회복지법인          107   107            107                107          107
# 직장              272   272            272                272          244
# 협동               39    39             39                 39           38
#
#                nursing_room_num  playground_num  CCTV_num  \
# day_care_type
# 가정                         1818            1493      2257
# 국공립                         796             697       992
# 민간                         1407            1161      1655
# 법인·단체                        79              63        88
# 사회복지법인                       68              58        71
# ...

# %%
df
# Out:
#        city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0     서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1     서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2     서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3     서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4     서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# ...     ...   ...           ...           ...                ...          ...
# 7546  부산광역시   금정구      해바라기어린이집            민간                 46         13.0
# 7547  부산광역시   금정구        해수어린이집            가정                 19          6.0
# 7548  부산광역시   금정구   행복한그림동산어린이집            민간                 92         16.0
# 7549  부산광역시   금정구       행복한어린이집            민간                 43         12.0
# 7550  부산광역시   금정구        혜인어린이집            민간                 32          7.0
#
# ...
