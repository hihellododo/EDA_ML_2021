# %%
import pandas as pd
import os
csv_path='D:\machine_learning_Data'
csv_list=os.listdir(csv_path)

csv_list_py=[file for file in csv_list if file.endswith('csv')]

# %%
csv_list_py
# Out:
# ['건축허가현황.csv',
#  '국내건설수주액.csv',
#  '미분양주택현황.csv',
#  '아파트 실거래가격지수.csv',
#  '유형별_주택월세통합가격지수.csv',
#  '주택건설인허가실적.csv',
#  '주택매매가격지수(KB).csv',
#  '주택전세가격지수(KB).csv',
#  '지역별_지가변동률.csv']

# %%
df=pd.read_csv('D:\machine_learning_Data\아파트 실거래가격지수.csv')
df
# Out:
#      Unnamed: 0  도심권[2017.11=100]  동북권[2017.11=100]  동남권[2017.11=100]  \
# 0    2006-01-01              59.3              59.0              62.0
# 1    2006-02-01              58.1              59.3              63.8
# 2    2006-03-01              59.5              59.5              66.4
# 3    2006-04-01              59.5              59.7              67.9
# 4    2006-05-01              61.4              59.6              67.1
# ..          ...               ...               ...               ...
# 176  2020-09-01             146.7             158.0             147.7
# 177  2020-10-01             147.1             159.4             148.1
# 178  2020-11-01             149.4             162.6             150.3
# 179  2020-12-01             152.5             166.1             153.5
# 180  2021-01-01             155.1             171.3             158.1
#
#      부산[2017.11=100]  대구[2017.11=100]  인천[2017.11=100]  광주[2017.11=100]  \
# ...

# %%
df0=pd.read_csv('D:\machine_learning_Data\건축허가현황.csv', encoding='utf-8')
df1=pd.read_csv('D:\machine_learning_Data\국내건설수주액.csv')
